# %%
import sympy as sp
import einsteinpy.symbolic as gr
sp.init_printing()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c76881620e24> in <module>
#       1 import sympy as sp
# ----> 2 import einsteinpy.symbolic as gr
#       3 sp.init_printing()
#
# ModuleNotFoundError: No module named 'einsteinpy'

# %%
t, r, theta, phi = sp.symbols('t, r, theta, phi')
u, a, c = sp.symbols('mu, a, c')
rhox, Dx, Ex = sp.symbols('rho, Delta, Sigma')

rho = sp.sqrt(r**2 + a**2*(sp.cos(theta))**2)
D = r**2 - 2*u*r + a**2
E = sp.sqrt((r**2 + a**2)**2 - a**2*D*(sp.sin(theta))**2)

n = 4

# %% [markdown]
# ## Métrica

# %%
metric = [[0 for i in range(4)] for i in range(4)]

metric[0][0] = sp.simplify((D - a**2*(sp.sin(theta))**2)/rho**2)
metric[0][3] = sp.simplify(2*u*a*r*(sp.sin(theta))**2/rho**2)
metric[1][1] = -rho**2/D
metric[2][2] = -rho**2
metric[3][0] = sp.simplify(2*u*a*r*(sp.sin(theta))**2/rho**2)
metric[3][3] = sp.simplify(-E**2*(sp.sin(theta))**2/rho**2)

coord = [t, r, theta, phi]
metric_gr = gr.MetricTensor(metric, coord)

metric_gr.tensor()
# Out:
# ⎡ 2    2               2
# ⎢a ⋅cos (θ) - 2⋅μ⋅r + r
# ⎢───────────────────────          0                  0
# ⎢     2    2       2
# ⎢    a ⋅cos (θ) + r
# ⎢
# ⎢                            2    2       2
# ⎢                         - a ⋅cos (θ) - r
# ⎢           0             ─────────────────          0
# ⎢                           2            2
# ⎢                          a  - 2⋅μ⋅r + r
# ⎢
# ⎢                                               2    2       2
# ⎢           0                     0          - a ⋅cos (θ) - r
# ⎢
# ⎢                                                               ⎛
# ⎢               2                                               ⎜ 2 ⎛ 2
# ⎢    2⋅a⋅μ⋅r⋅sin (θ)                                            ⎝a ⋅⎝a  - 2⋅μ⋅
# ⎢    ───────────────              0                  0          ──────────────
# ⎢     2    2       2
# ⎣    a ⋅cos (θ) + r
#
#                2                     ⎤
#     2⋅a⋅μ⋅r⋅sin (θ)                  ⎥
# ...

# %%
metricx = metric_gr.subs([(r**2 + a**2*(sp.cos(theta))**2, rhox**2), (r**2 - 2*u*r + a**2, Dx)])
metricx = metricx.subs((r**2 + a**2)**2 - a**2*Dx*(sp.sin(theta))**2, Ex**2)


metricx.tensor()
# Out:
# ⎡            2                          2   ⎤
# ⎢  -2⋅μ⋅r + ρ                2⋅a⋅μ⋅r⋅sin (θ)⎥
# ⎢  ───────────     0     0   ───────────────⎥
# ⎢        2                           2      ⎥
# ⎢       ρ                           ρ       ⎥
# ⎢                                           ⎥
# ⎢                   2                       ⎥
# ⎢                 -ρ                        ⎥
# ⎢       0         ────   0          0       ⎥
# ⎢                  Δ                        ⎥
# ⎢                                           ⎥
# ⎢                         2                 ⎥
# ⎢       0          0    -ρ          0       ⎥
# ⎢                                           ⎥
# ⎢           2                   2    2      ⎥
# ⎢2⋅a⋅μ⋅r⋅sin (θ)              -Σ ⋅sin (θ)   ⎥
# ⎢───────────────   0     0    ────────────  ⎥
# ⎢        2                          2       ⎥
# ⎣       ρ                          ρ        ⎦

# %% [markdown]
# ## Métrica inversa $g^{\mu \nu}$

# %%
#inv = sp.simplify(metric_gr.inv())

#inv

# %%
#invx = inv.subs([(r**2 + a**2*(sp.cos(theta))**2, rhox), (r**2 - 2*u*r + a**2, Dx)])
#invx = invx.subs((r**2 + a**2)**2 - a**2*Dx*(sp.sin(theta))**2, Ex)

#invx

# %% [markdown]
# ## Christoffel

# %%
chris = gr.ChristoffelSymbols.from_metric(metric_gr)

# %%
for i in range(n):
    for j in range(n):
        for k in range(n):
            if j != k:
                if chris[i, j, k] != 0:
                    chrisx = sp.simplify(chris[i, j, k].subs([(r**2 + a**2*(sp.cos(theta))**2, rhox), (r**2 - 2*u*r + a**2, Dx)]))
                    chrisx = chrisx.subs((r**2 + a**2)**2 - a**2*Dx*(sp.sin(theta))**2, Ex)
                   # chrisx = 
                    chrisx = chrisx.ratsimp().cancel()
                    chrisx = chrisx.factor()

                    display([i, j, k], chrisx)
# Out:
# [0, 0, 1]
#     ⎛        2        2   ⎞ ⎛   2    ⎞
#  -μ⋅⎝-Σ + 2⋅a ⋅μ⋅r⋅sin (θ)⎠⋅⎝2⋅r  - ρ⎠
# ───────────────────────────────────────
#   ⎛                    2  2  2    2   ⎞
# ρ⋅⎝-2⋅Σ⋅μ⋅r + Σ⋅ρ + 4⋅a ⋅μ ⋅r ⋅sin (θ)⎠
# [0, 0, 2]
#    2     ⎛        2        2             ⎞
# 2⋅a ⋅μ⋅r⋅⎝-Σ + 2⋅a ⋅μ⋅r⋅sin (θ) + 2⋅μ⋅r⋅ρ⎠⋅sin(θ)⋅cos(θ)
# ────────────────────────────────────────────────────────
#           ⎛                    2  2  2    2   ⎞
#         ρ⋅⎝-2⋅Σ⋅μ⋅r + Σ⋅ρ + 4⋅a ⋅μ ⋅r ⋅sin (θ)⎠
# [0, 1, 0]
#     ⎛        2        2   ⎞ ⎛   2    ⎞
#  -μ⋅⎝-Σ + 2⋅a ⋅μ⋅r⋅sin (θ)⎠⋅⎝2⋅r  - ρ⎠
# ───────────────────────────────────────
#   ⎛                    2  2  2    2   ⎞
# ρ⋅⎝-2⋅Σ⋅μ⋅r + Σ⋅ρ + 4⋅a ⋅μ ⋅r ⋅sin (θ)⎠
# [0, 1, 3]
#      ⎛   2    2       4      2        2         2  2    2         2  2      4⎞
# -a⋅μ⋅⎝Δ⋅a ⋅sin (θ) - a  + 2⋅a ⋅μ⋅r⋅sin (θ) - 2⋅a ⋅r ⋅sin (θ) + 2⋅a ⋅r  + 3⋅r ⎠
# ──────────────────────────────────────────────────────────────────────────────
# ...

# %% [markdown]
# # Ricci

# %%
rie = gr.RiemannCurvatureTensor.from_christoffels(chris)

for i in range(n):
    for j in range(n):
        for k in range(n):
            if j != k:
                if rie[i, j, k] != 0:
                    riex = sp.simplify(chris[i, j, k].subs([(r**2 + a**2*(sp.cos(theta))**2, rhox), (r**2 - 2*u*r + a**2, Dx)]))
                    riex = chrisx.subs((r**2 + a**2)**2 - a**2*Dx*(sp.sin(theta))**2, Ex)
                    #chrisx = 
                    riex = chrisx.ratsimp().cancel()
                    riex = chrisx.factor()

                    display([i, j, k], riex)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8b10fa8b758c> in <module>
# ----> 1 rie = gr.RiemannCurvatureTensor.from_christoffels(chris)
#       2
#       3 for i in range(n):
#       4     for j in range(n):
#       5         for k in range(n):
#
# ~/anaconda3/lib/python3.7/site-packages/einsteinpy/symbolic/riemann.py in from_christoffels(cls, chris, parent_metric)
#      84             for p in range(dims):
#      85                 temp += arr[p, s, n] * arr[t, p, r] - arr[p, r, n] * arr[t, p, s]
# ---> 86             riemann_list[t][s][r][n] = sympy.simplify(temp)
#      87         if parent_metric is None:
#      88             parent_metric = chris.parent_metric
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse)
#     580
# ...
